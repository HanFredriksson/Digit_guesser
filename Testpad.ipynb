# %% [markdown]
# # Meant for testing the app for guessing the handwriten numbers

# %%
#import

import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import pandas as pd

# %%
# train model for guessing

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
trainset = torchvision.datasets.MNIST(root='./data/', train=True, download=True, transform=transform)
testset = torchvision.datasets.MNIST(root='./data/', train=False, download=True, transform=transform)



X_train = trainset.data.reshape([60000, 784])
y_train = trainset.targets

X_test = testset.data.reshape([10000, 784])
y_test = testset.targets

KNN_model = KNeighborsClassifier()
KNN_model = KNeighborsClassifier(n_neighbors=2)
KNN_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
KNN_accu = {}

for k_value in range(1, 10):
    KNN_model = KNeighborsClassifier(n_neighbors=k_value)
    KNN_model.fit(X_train, y_train)
    KNN_y = KNN_model.predict(X_test)

    KNN_accu[f"K value {k_value}"] = (accuracy_score(y_test, KNN_y)*100)

# %%
KNN_accu_report = pd.DataFrame(KNN_accu, index=["%"])

KNN_accu_report
# Out:
#    K value 1  K value 2  K value 3  K value 4  K value 5  K value 6  \
# %      96.91      96.27      97.05      96.82      96.88      96.77
#
#    K value 7  K value 8  K value 9
# %      96.94       96.7      96.59

# %%
plt.plot(KNN_accu_report, KNN_accu_report, marker="o")
plt.xlabel("K-values")
plt.ylabel("Accuracy")
plt.title("KNN on handwriten digits");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 plt.plot(KNN_accu_report.columns, KNN_accu_report, marker="o")
#       2 plt.xlabel("K-values")
#       3 plt.ylabel("Accuracy")
#
# File f:\AI-24-programering\Python-programing-Hannes-Fredriksson\.venv\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# ...

# %%
cm = confusion_matrix(y_test, KNN_y)
ConfusionMatrixDisplay(cm).plot();

# %%
# Gets the handdrawn digit

# %%
# Presents the anwser


KNN_y = KNN_model.predict(user_digit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Presents the anwser
# ----> 4 KNN_y = KNN_model.predict(user_digit)
#
# NameError: name 'user_digit' is not defined
